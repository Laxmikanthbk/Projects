# %%
import gui_frontend

# %%
# !pip3 install tesseract
# Out:
# Requirement already satisfied: tesseract in c:\users\laxmikanth kacheri\.conda\lib\site-packages (0.1.3)

# %%
gui_frontend.start_gui()
# Out:
# step 2 - len(contours) = 479
# step 2 - intCountOfPossibleChars = 32
# step 2 - len(listOfPossibleCharsInScene) = 32
# step 3 - listOfListsOfMatchingCharsInScene.Count = 1
# 1 possible plates found
# possible plate 0
# plate detection complete....
# char detection complete,
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\Laxmikanth Kacheri\.conda\lib\site-packages\pytesseract\pytesseract.py", line 252, in run_tesseract
#     proc = subprocess.Popen(cmd_args, **subprocess_args())
#   File "C:\Users\Laxmikanth Kacheri\.conda\lib\subprocess.py", line 858, in __init__
#     self._execute_child(args, executable, preexec_fn, close_fds,
#   File "C:\Users\Laxmikanth Kacheri\.conda\lib\subprocess.py", line 1311, in _execute_child
#     hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
# FileNotFoundError: [WinError 2] The system cannot find the file specified
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Laxmikanth Kacheri\.conda\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
#   File "D:\MPLAXMIKANTH\ezyzip\gui_backend.py", line 126, in START
#     number_plate_out(img)
#   File "D:\MPLAXMIKANTH\ezyzip\gui_backend.py", line 30, in number_plate_out
#     product.main(image)
#   File "D:\MPLAXMIKANTH\ezyzip\product.py", line 70, in main
#     text = pytesseract.image_to_string(licPlate.imgPlate, config=config)
#   File "C:\Users\Laxmikanth Kacheri\.conda\lib\site-packages\pytesseract\pytesseract.py", line 413, in image_to_string
#     return {
#   File "C:\Users\Laxmikanth Kacheri\.conda\lib\site-packages\pytesseract\pytesseract.py", line 416, in <lambda>
#     Output.STRING: lambda: run_and_get_output(*args),
#   File "C:\Users\Laxmikanth Kacheri\.conda\lib\site-packages\pytesseract\pytesseract.py", line 284, in run_and_get_output
#     run_tesseract(**kwargs)
#   File "C:\Users\Laxmikanth Kacheri\.conda\lib\site-packages\pytesseract\pytesseract.py", line 256, in run_tesseract
#     raise TesseractNotFoundError()
# pytesseract.pytesseract.TesseractNotFoundError: tesseract is not installed or it's not in your PATH. See README file for more information.
# step 2 - len(contours) = 479
# step 2 - intCountOfPossibleChars = 32
# step 2 - len(listOfPossibleCharsInScene) = 32
# step 3 - listOfListsOfMatchingCharsInScene.Count = 1
# 1 possible plates found
# possible plate 0
# plate detection complete....
# char detection complete,
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\Laxmikanth Kacheri\.conda\lib\site-packages\pytesseract\pytesseract.py", line 252, in run_tesseract
#     proc = subprocess.Popen(cmd_args, **subprocess_args())
#   File "C:\Users\Laxmikanth Kacheri\.conda\lib\subprocess.py", line 858, in __init__
#     self._execute_child(args, executable, preexec_fn, close_fds,
#   File "C:\Users\Laxmikanth Kacheri\.conda\lib\subprocess.py", line 1311, in _execute_child
#     hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
# FileNotFoundError: [WinError 2] The system cannot find the file specified
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Laxmikanth Kacheri\.conda\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
#   File "D:\MPLAXMIKANTH\ezyzip\gui_backend.py", line 126, in START
#     number_plate_out(img)
#   File "D:\MPLAXMIKANTH\ezyzip\gui_backend.py", line 30, in number_plate_out
#     product.main(image)
#   File "D:\MPLAXMIKANTH\ezyzip\product.py", line 70, in main
#     text = pytesseract.image_to_string(licPlate.imgPlate, config=config)
#   File "C:\Users\Laxmikanth Kacheri\.conda\lib\site-packages\pytesseract\pytesseract.py", line 413, in image_to_string
#     return {
#   File "C:\Users\Laxmikanth Kacheri\.conda\lib\site-packages\pytesseract\pytesseract.py", line 416, in <lambda>
#     Output.STRING: lambda: run_and_get_output(*args),
#   File "C:\Users\Laxmikanth Kacheri\.conda\lib\site-packages\pytesseract\pytesseract.py", line 284, in run_and_get_output
#     run_tesseract(**kwargs)
#   File "C:\Users\Laxmikanth Kacheri\.conda\lib\site-packages\pytesseract\pytesseract.py", line 256, in run_tesseract
#     raise TesseractNotFoundError()
# pytesseract.pytesseract.TesseractNotFoundError: tesseract is not installed or it's not in your PATH. See README file for more information.
# step 2 - len(contours) = 479
# step 2 - intCountOfPossibleChars = 32
# step 2 - len(listOfPossibleCharsInScene) = 32
# step 3 - listOfListsOfMatchingCharsInScene.Count = 1
# 1 possible plates found
# possible plate 0
# plate detection complete....
# char detection complete,
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\Laxmikanth Kacheri\.conda\lib\site-packages\pytesseract\pytesseract.py", line 252, in run_tesseract
#     proc = subprocess.Popen(cmd_args, **subprocess_args())
#   File "C:\Users\Laxmikanth Kacheri\.conda\lib\subprocess.py", line 858, in __init__
#     self._execute_child(args, executable, preexec_fn, close_fds,
#   File "C:\Users\Laxmikanth Kacheri\.conda\lib\subprocess.py", line 1311, in _execute_child
#     hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
# FileNotFoundError: [WinError 2] The system cannot find the file specified
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Laxmikanth Kacheri\.conda\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
#   File "D:\MPLAXMIKANTH\ezyzip\gui_backend.py", line 126, in START
#     number_plate_out(img)
#   File "D:\MPLAXMIKANTH\ezyzip\gui_backend.py", line 30, in number_plate_out
#     product.main(image)
#   File "D:\MPLAXMIKANTH\ezyzip\product.py", line 70, in main
#     text = pytesseract.image_to_string(licPlate.imgPlate, config=config)
#   File "C:\Users\Laxmikanth Kacheri\.conda\lib\site-packages\pytesseract\pytesseract.py", line 413, in image_to_string
#     return {
#   File "C:\Users\Laxmikanth Kacheri\.conda\lib\site-packages\pytesseract\pytesseract.py", line 416, in <lambda>
#     Output.STRING: lambda: run_and_get_output(*args),
#   File "C:\Users\Laxmikanth Kacheri\.conda\lib\site-packages\pytesseract\pytesseract.py", line 284, in run_and_get_output
#     run_tesseract(**kwargs)
#   File "C:\Users\Laxmikanth Kacheri\.conda\lib\site-packages\pytesseract\pytesseract.py", line 256, in run_tesseract
#     raise TesseractNotFoundError()
# pytesseract.pytesseract.TesseractNotFoundError: tesseract is not installed or it's not in your PATH. See README file for more information.

# %%
pip install PyMuPDF

# %% [markdown]
# ## gui_frontend.start_gui()

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2
import os

# %%
import cv2
import matplotlib.pyplot as plt

im=cv2.imread("Dataset/1.jpeg")
plt.imshow(im)
plt.show()
im_gray=cv2.GaussianBlur(im, (7, 7), 0)
plt.imshow(im_gray)
plt.show()

# %%
# !pip install opencv-python
